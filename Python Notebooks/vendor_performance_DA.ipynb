# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.connect(  # TO CONNECT TO db
    host="localhost",       # or your db server address
    user="root",   # your MySQL username
    password="root", # your MySQL password
    database="inventory"   # optional: specify the db/schema to use
)

print(conn)

# %%
cursor = conn.cursor()    # (Optional) Use a Cursor to Interact with the Database
cursor.execute("SHOW TABLES")  # used to view db within the db.
for x in cursor:
    print(x)
# Out:
# ('begin_inventory',)
# ('end_inventory',)
# ('purchase_prices',)
# ('purchases',)
# ('sales',)
# ('vendor_invoice',)

# %%
pd.read_sql("select count(*) from purchases",conn)  #to read number of rows in a table.
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\3632615351.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select count(*) from purchases",conn)  #to read number of rows in a table.
#    count(*)
# 0   2372474

# %%
#Get all table names from the database
cursor.execute("SHOW TABLES")
tables = [row[0] for row in cursor.fetchall()]

# %%
# For each table, count the number of records
for table in tables:
    cursor.execute(f"SELECT COUNT(*) FROM `{table}`")
    count = cursor.fetchone()[0]
    print(f"Table '{table}' has {count} records.")
# Out:
# Table 'begin_inventory' has 431018 records.
# Table 'end_inventory' has 0 records.
# Table 'purchase_prices' has 12261 records.
# Table 'purchases' has 2372474 records.
# Table 'sales' has 51301452 records.
# Table 'vendor_invoice' has 5543 records.

# %%
purchases = pd.read_sql_query("select * from purchases where VendorNumber = 4466",conn)
purchases
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\1657624297.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   purchases = pd.read_sql_query("select * from purchases where VendorNumber = 4466",conn)
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# ...

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchase_prices = pd.read_sql_query("select * from purchase_prices",conn)
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\1311750002.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   purchase_prices = pd.read_sql_query("select * from purchase_prices",conn)

# %%
purchase_prices
# Out:
#        Brand                   Description  Price    Size  Volume  \
# 0         58   Gekkeikan Black & Gold Sake  12.99   750mL   750.0
# 1         62      Herradura Silver Tequila  36.99   750mL   750.0
# 2         63    Herradura Reposado Tequila  38.99   750mL   750.0
# 3         72          No. 3 London Dry Gin  34.99   750mL   750.0
# 4         75     Three Olives Tomato Vodka  14.99   750mL   750.0
# ...      ...                           ...    ...     ...     ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99   750mL   750.0
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99   750mL   750.0
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99   750mL   750.0
# 12259  46011       Folonari Pnt Nr Venezie  12.99  1500ml  1500.0
# 12260  46964     Calera Viognier Mt Harlan  35.99   750mL   750.0
#
#        Classification  PurchasePrice  VendorNumber  \
# 0                   1           9.28          8320
# 1                   1          28.67          1128
# ...

# %% [markdown]
# The purchases table contains actual purchase data, including the date of purchase, products (brands) purchased by vendors, the amount paid (in dollars), and the quantity purchased.
# The purchase price column is derived from the purchase_prices table, which provides product-wise actual and purchase prices. The combination of vendor and brand is unique in this table.
# The vendor_invoice table aggregates data from the purchases table, summarizing quantity and dollar amounts, along with an additional column for freight.
# This table maintains uniqueness based on vendor and PO number.
# The sales table captures actual sales transactions, detailing the brands purchased by vendors, the quantity sold, the selling price, and the revenue earned.

# %% [markdown]
# Dollar = price*qty (applied to all tables)

# %% [markdown]
# As the data that we need for analysis is distributed in different tables, we need to create a summary table containing:
# >purchase transactions made by vendors
# >sales transaction data
# >freight costs for each vendor
# >actual product prices from vendors

# %%
vendor_invoice = pd.read_sql_query("select * from vendor_invoice",conn)
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\3378658530.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vendor_invoice = pd.read_sql_query("select * from vendor_invoice",conn)

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""select VendorNumber,sum(freight) as FreightCost
from vendor_invoice
group by VendorNumber""",conn)
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\4136410428.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   freight_summary = pd.read_sql_query("""select VendorNumber,sum(freight) as FreightCost

# %%
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0             105        62.39
# 1            4466       793.91
# 2             388       211.74
# 3             480     89286.27
# 4             516      8510.41
# ..            ...          ...
# 121        201359         0.09
# 122          4901         0.72
# 123         90059        74.84
# 124          5083        10.68
# 125            54         0.48
#
# [126 rows x 2 columns]

# %%
# pd.read_sql_query("""select 
# p.VendorNumber,p.VendorName,p.Brand,p.PurchasePrice,
# pp.Volume, pp.Price as ActualPrice,
# SUM(p.Quantity) as TotalPurchasequantity,
# SUM(p.Dollars) as TotalPurchaseDollars
# from
# purchases p join 
# purchase_prices pp
# on p.Brand = pp.Brand
# where p.PurchasePrice > 0
# group by p.VendorNumber,p.VendorName,p.Brand,p.PurchasePrice,pp.Volume, pp.Price
# order by TotalPurchaseDollars""",conn)
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\324797898.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""select
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74
# 3              8004  SAZERAC CO INC                5683           0.39
# 4              9815  WINE GROUP INC                8527           1.32
# ...             ...                          ...    ...            ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17
# ...

# %%
# sales_copy = pd.read_sql_query("select * from sales where VendorNo = 12456", conn)

# %%
# sales_copy.columns

# %%
# pd.read_sql_query("""select
# VendorNo,Brand,
# sum(SalesDollars) as TotalSalesDollars,
# sum(SalesPrice) as TotalSalesPrice,
# sum(SalesQuantity) as TotalSalesQuantity,
# sum(ExciseTax) as TotalExciseTax
# from
# sales 
# group by VendorNo,Brand
# order by TotalSalesDollars""",conn)

# %%
vendor_sales_summary = pd.read_sql_query(  # here we join 3 CTEs FreightSummary,PurchaseSummary,SalesSummary to get an aggregated table. Within CTEs we have joined multiple tables
    """with FreightSummary as(
select VendorNumber,sum(freight) as FreightCost
from vendor_invoice
group by VendorNumber
),
PurchaseSummary as(
select 
p.VendorNumber,p.VendorName,p.Brand,p.Description,p.PurchasePrice,
pp.Volume, pp.Price as ActualPrice,
SUM(p.Quantity) as TotalPurchasequantity,
SUM(p.Dollars) as TotalPurchaseDollars
from
purchases p join 
purchase_prices pp
on p.Brand = pp.Brand
where p.PurchasePrice > 0
group by p.VendorNumber,p.VendorName,p.Brand,p.Description,p.PurchasePrice,pp.Volume, pp.Price
),
SalesSummary as(
select
VendorNo,Brand,
sum(SalesDollars) as TotalSalesDollars,
sum(SalesPrice) as TotalSalesPrice,
sum(SalesQuantity) as TotalSalesQuantity,
sum(ExciseTax) as TotalExciseTax
from
sales
group by
VendorNo,Brand
)
select
	ps.VendorNumber,ps.VendorName,ps.Brand,ps.Description,ps.PurchasePrice, ps.ActualPrice,ps.Volume,ps.TotalPurchasequantity,ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity,ss.TotalSalesDollars,ss.TotalSalesPrice,ss.TotalExciseTax,
    fs.FreightCost
from
	PurchaseSummary ps
left join SalesSummary ss
on ps.VendorNumber = ss.VendorNo
and ps.Brand = ss.Brand
left join FreightSummary fs
on ps.VendorNumber = fs.VendorNumber
order by ps.TotalPurchaseDollars desc"""
,conn)
# Out:
# C:\Users\n8nik\AppData\Local\Temp\ipykernel_10552\2519840256.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vendor_sales_summary = pd.read_sql_query(  # here we join 3 CTEs FreightSummary,PurchaseSummary,SalesSummary to get an aggregated table. Within CTEs we have joined multiple tables

# %%
vendor_sales_summary #from the above query we got an aggregated table like below with all the information
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %% [markdown]
# This query generates a vendor wise sales and purchase summary, which is valuable for:
#
# Performance Optimization:
# The query involves heavy joins and aggregations on large datasets like sales and purchases.
# Storing the pre-aggregated results avoids repeated expensive computations.
# Helps in analyzing sales, purchases, and pricing for different vendors and brands.
# Future Benefits of Storing this data for faster Dashboarding & Reporting.
# Instead of running expensive queries each time, dashboards can fetch data quickly from vendor_sales_summary.

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                   float64
# TotalPurchasequantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# SalestoPurchaseRatio     float64
# StockTurnover            float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()  #to check missing/null values in columns
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchasequantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalSalesPrice          178
# TotalExciseTax           178
# FreightCost                0
# SalestoPurchaseRatio     178
# StockTurnover            178
# dtype: int64

# %%
vendor_sales_summary['VendorName'].unique()  # to check any trailing/ leading whitespaces in the column. Here we can see some vnames have leading whitespaces which needs removal
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
vendor_sales_summary['Description'].unique()
# Out:
# array(['Jack Daniels No 7 Black', "Tito's Handmade Vodka",
#        'Absolut 80 Proof', ..., 'Crown Royal Apple',
#        'Concannon Glen Ellen Wh Zin', 'The Club Strawbry Margarita'],
#       shape=(9651,), dtype=object)

# %%
vendor_sales_summary['Description'].apply(lambda x: x != x.strip()).any() # this code is used to find if a column has leading/trailing whitesapces. Output np.True_ means there 
                                                                    #are whitesapces. np.False_ means no whitespaces.
# Out:
# np.False_

# %%
# Steps to check which rows have leading and trailing whitespaces in VendorName column


# 1. Create a mask for rows with leading/trailing whitespace in 'VendorName'
whitespace_mask = vendor_sales_summary['VendorName'] != vendor_sales_summary['VendorName'].str.strip()

# 2. Filter rows where the mask is True
rows_with_whitespace = vendor_sales_summary[whitespace_mask]

# 3. Display those rows
print(vendor_sales_summary.loc[whitespace_mask, 'VendorName'])
# Out:
# 0        BROWN-FORMAN CORP
# 2        PERNOD RICARD USA
# 3        DIAGEO NORTH AMERICA INC
# 4        DIAGEO NORTH AMERICA INC
# 5        BACARDI USA INC
#                     ...
# 10687    WINE GROUP INC
# 10688    SAZERAC CO INC
# 10689    HEAVEN HILL DISTILLERIES
# 10690    DIAGEO NORTH AMERICA INC
# 10691    PROXIMO SPIRITS INC.
# Name: VendorName, Length: 9137, dtype: object

# %%
vendor_sales_summary.fillna(0,inplace=True)  # this is to replace all NULL values in df with 0

# %%
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'].str.strip()  # to strip all leading/trailing whitespaces from VendorName column

# %%
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
#  We need to find Gross Profit . For this we have to create a new column.

vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesDollars'] - vendor_sales_summary['TotalPurchaseDollars']

# %%
has_negative = (vendor_sales_summary['GrossProfit'] < 0).any()
print(has_negative)  # True if any negative values exist, False otherwise
# Out:
# True

# %%
min_value = vendor_sales_summary['GrossProfit'].min()

print(min_value)
# Out:
# -28614.08

# %%
# column to calculate PROFIT MARGIN % 

vendor_sales_summary['ProfitMargin%'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalPurchaseDollars'])*100

# %%
# column to calculate STOCK TURNOVER . This calculates how many purchase qty was there (bought/in stock) and how many qty were sold.
# ex: 10 qty was bought and 10 were sold. Here o/p is 1 that means all qty were sold. If o/p is less than 1 like 0.8 means less qty were sold.
# If o/p is more than 1 like 1.5 that means more qty was sold. This can be due to old stock qty already being there in stock that was sold.

vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalPurchasequantity']

# %%
# Column to calculate Sales to Purchase ratio

vendor_sales_summary['SalestoPurchaseRatio'] = vendor_sales_summary['TotalSalesDollars']/vendor_sales_summary['TotalPurchaseDollars']

# %%
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary.to_excel('vendor_sales_summary.xlsx', index=False)

# %% [markdown]
# In this file vendor_performance_DA.ipynb we have:
# 1. Imported data from DB
# 2. Created an aggregated table with all required data.
# 3. Created new columns with required metrics.
# 4. Saved it back in a excel file 'vendor_sales_summary.xlsx'. In the video the lady saved it back to the DB and created a script to repeat this task for repetitive tasks in
#    companies.
